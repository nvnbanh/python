# %%
print("hello")
x=1
y=2
print(x+y)
print("tiep tuc")
# Out:
# hello
# 3
# tiep tuc

# %%
print("next")
# Out:
# next

# %%
hall = 11.25
kit = 18.0
liv = 20.0
bed = 10.75
bath = 9.50
areas = [hall, kit, liv, bed, bath]
print(areas)
# Out:
# [11.25, 18.0, 20.0, 10.75, 9.5]

# %%
house =[["hallway", hall],
        ["kitchen", kit],
        ["living room", liv]]
print(house)
print(type(house))
# Out:
# [['hallway', 11.25], ['kitchen', 18.0], ['living room', 20.0]]
# <class 'list'>
